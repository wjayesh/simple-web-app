# %% [markdown]
# # Getting the Response From ESPN API and Converting it into a JSON file

# %%
# Import a library that allows to make HTTP request
import requests
import json
# Set the API endpoint
url = "https://hs-consumer-api.espncricinfo.com/v1/pages/matches/current?lang=en&latest=true"

# Use the library to perform an HTTP GET request to the URL
response = requests.get(url)
response_dict = json.loads(response.text)

# %% [markdown]
# # Function to clear Html tags

# %%
import re
CLEANR = re.compile('<.*?>') 

def cleanhtml(raw_html):
  cleantext = re.sub(CLEANR, '', raw_html)
  return cleantext

# %% [markdown]
# # Generating Summary of Ongoing Matches

# %%
summary_msg = []
summary_msg.append("---CURRENT GAMES IN LIST---")
for match_dict in response_dict['matches']:
    match_details = match_dict['slug'].upper()
    match_status = match_dict['statusText']
    summary_msg.append("---")
    summary_msg.append(match_details)
    summary_msg.append(match_status)
    try:
        teams={}
        toss ={}
        toss.update({1 : "Bat"})
        toss.update({2 : "Bowl"})
        for team in match_dict['teams']:
            team_name = team['team']['name']
            team_id = team['team']['id']
            teams.update({team_id : team_name})
        tossId = match_dict['tossWinnerTeamId']
        fieldId = match_dict['tossWinnerChoice']
        toss_status = "{} have won the toss and decided to {} first".format(teams[tossId],toss[fieldId])
        summary_msg.append(toss_status)
    except:
        pass
    summary_msg.append("---")

# %%
for msg in summary_msg:
    print(msg)
# Out:
# ---CURRENT GAMES IN LIST---
# ---
# AUSTRALIA-VS-ENGLAND-2ND-TEST
# Day 4 - England need 386 runs.
# Australia have won the toss and decided to Bat first
# ---
# ---
# BALOCHISTAN-VS-NORTHERN-PAKISTAN-28TH-MATCH
# Northern lead by 144 runs.
# Northern have won the toss and decided to Bowl first
# ---
# ---
# SINDH-VS-SOUTHERN-PUNJAB-PAKISTAN-29TH-MATCH
# Southern PNJ lead by 25 runs.
# Southern PNJ have won the toss and decided to Bowl first
# ---
# ---
# KHYBER-PAKHTUNKHWA-VS-CENTRAL-PUNJAB-PAKISTAN-30TH-MATCH
# Khyber lead by 334 runs.
# Central PNJB have won the toss and decided to Bowl first
# ---
# ---
# WELLINGTON-WOMEN-VS-CANTERBURY-WOMEN-9TH-MATCH
# Well Women won by 45 runs
# Well Women have won the toss and decided to Bat first
# ---
# ---
# TASMANIA-WOMEN-VS-QUEENSLAND-WOMEN-4TH-MATCH
# Tas Women won by 5 wickets (with 5 balls remaining) (D/L method)
# Tas Women have won the toss and decided to Bowl first
# ---
# ---
# VICTORIA-WOMEN-VS-NEW-SOUTH-WALES-WOMEN-3RD-MATCH
# NSW Women won by 26 runs (D/L method)
# VIC Women have won the toss and decided to Bowl first
# ---
# ---
# WELLINGTON-VS-CANTERBURY-9TH-MATCH
# Canterbury won by 6 wickets (with 21 balls remaining)
# Wellington have won the toss and decided to Bat first
# ---
# ---
# HONG-KONG-ISLANDERS-VS-KOWLOON-LIONS-3RD-MATCH
# Islanders won by 13 runs
# Islanders have won the toss and decided to Bat first
# ---
# ---
# NORTH-ZONE-BANGLADESH-VS-SOUTH-ZONE-BANGLADESH-3RD-MATCH
# Day 1 - South Z (BD) chose to field.
# South Z (BD) have won the toss and decided to Bowl first
# ---
# ---
# CENTRAL-ZONE-BANGLADESH-VS-EAST-ZONE-BANGLADESH-4TH-MATCH
# Day 1 - Cent Z (BD) trail by 241 runs.
# Cent Z (BD) have won the toss and decided to Bowl first
# ---
# ---
# LUMBINI-PROVINCE-WOMEN-VS-KARNALI-PROVINCE-WOMEN-GROUP-A
# Lumbini Wmn won by 10 wickets (with 17 balls remaining)
# Karnali Wmn have won the toss and decided to Bat first
# ---
# ---
# KARNATAKA-VS-RAJASTHAN-PRELIMINARY-QUARTER-FINAL
# Karnataka won by 8 wickets (with 38 balls remaining)
# Karnataka have won the toss and decided to Bowl first
# ---
# ---
# UTTAR-PRADESH-VS-MADHYA-PRADESH-PRELIMINARY-QUARTER-FINAL
# U. Pradesh won by 5 wickets (with 5 balls remaining)
# U. Pradesh have won the toss and decided to Bowl first
# ---
# ---
# VIDARBHA-VS-TRIPURA-PRELIMINARY-QUARTER-FINAL
# Vidarbha won by 34 runs
# Tripura have won the toss and decided to Bowl first
# ---
# ---
# PROVINCE-NUMBER-1-WOMEN-VS-BAGMATI-PROVINCE-WOMEN-GROUP-A
# PROV-1 Women won by 55 runs
# PROV-1 Women have won the toss and decided to Bat first
# ---
# ---
# BRISBANE-HEAT-VS-SYDNEY-THUNDER-14TH-MATCH
# Thunder won by 53 runs
# Heat have won the toss and decided to Bowl first
# ---
# ---
# COLOMBO-STARS-VS-DAMBULLA-GIANTS-ELIMINATOR
# Giants won by 6 wickets (with 7 balls remaining)
# Stars have won the toss and decided to Bat first
# ---
# ---
# JAFFNA-KINGS-VS-GALLE-GLADIATORS-QUALIFIER-1
# Gladiators won by 64 runs
# Kings have won the toss and decided to Bowl first
# ---
# ---
# AUCKLAND-WOMEN-VS-NORTHERN-DISTRICTS-WOMEN-10TH-MATCH
# Match yet to begin
# ---
# ---
# AUCKLAND-VS-NORTHERN-DISTRICTS-10TH-MATCH
# Match starts in {{MATCH_START_HOURS}} {{MATCH_START_MINS}}
# ---
# ---
# ARMED-POLICE-FORCE-WOMEN-VS-PROVINCE-NUMBER-2-WOMEN-GROUP-B
# Match yet to begin
# ---
# ---
# GANDAKI-PROVINCE-WOMEN-VS-SUDUR-PASCHIM-PROVINCE-WOMEN-GROUP-B
# Match yet to begin
# ---
# ---
# PERTH-SCORCHERS-VS-HOBART-HURRICANES-15TH-MATCH
# Match yet to begin
# ---

# %% [markdown]
# # Getting The IDs of Current Games

# %%
game_ids = []
for match_dict in response_dict['matches']:
    if match_dict['coverage']=="Y":
        series_id = match_dict['series']['objectId']
        match_id = match_dict['objectId']
        game_ids.append((series_id,match_id))

# %%
game_ids
# Out:
# [(1263452, 1263463),
#  (1289602, 1289614),
#  (1293040, 1293043),
#  (1293683, 1293716),
#  (1280193, 1280400),
#  (1293683, 1293717),
#  (1269637, 1269651),
#  (1291193, 1291215),
#  (1291193, 1291216),
#  (1289602, 1289604),
#  (1293683, 1293763),
#  (1293683, 1293764),
#  (1269637, 1269652)]

# %%
game_msgs = []
game_msgs.append(["-----------------------------------------------------------------------------------------"])
game_msgs.append(["-------------------------------------NEW UPDATES ----------------------------------------"])
for game_id in game_ids[:3]:
    final_msgs=[]
    final_msgs.append("--------------------------------------------------")
    # Set the API endpoint
    url = "https://hs-consumer-api.espncricinfo.com/v1/pages/match/details?lang=en&seriesId={}&matchId={}&latest=true".format(game_id[0],game_id[1])

    # Use the library to perform an HTTP GET request to the URL
    response = requests.get(url)
    response_dict = json.loads(response.text)
    
    # Generating Initial Message
    match_details = response_dict['match']['slug'].upper()
    match_status = response_dict['match']['statusText']
    final_msgs.append(match_details)
    final_msgs.append(match_status)
    final_msgs.append("Status: " + response_dict['match']['status'])
    # Getting the current score
   
    curr_score = response_dict['match']['teams'][0]['score']
    country = response_dict['match']['teams'][0]['team']['name']
    country_2 = response_dict['match']['teams'][1]['team']['name']
    curr_score_2 = response_dict['match']['teams'][1]['score']
    msg_1 = "{}'s score is: {}".format(country, curr_score)
    msg_2 = "{}'s score is: {}".format(country_2, curr_score_2)
    msg_1 = msg_1.replace("&","and")
    msg_2 = msg_2.replace("&","and")
    final_msgs.append(msg_1)  
    final_msgs.append(msg_2)
    # Getting the recent commentaries
    i = 0
    try:
        for comments in response_dict['recentBallCommentary']['ballComments']:
            if comments['isFour'] or comments['isSix'] or comments['isWicket'] or i==0 or comments['over'] != None:
                overs = comments['oversActual']
                overnum = comments['overNumber']
                ballnum = comments['ballNumber']
                innings = comments['inningNumber']
                if comments['over'] != None:
                    batsman_1 = comments['over']['overEndBatsmen'][0]['player']['longName']
                    batsman_2 = comments['over']['overEndBatsmen'][1]['player']['longName']
                    bowler_1 = comments['over']['overEndBowlers'][0]['player']['longName']
                    bowler_2 = comments['over']['overEndBowlers'][1]['player']['longName']
                    batsmen = "Batsmen in crease: {} and {}".format(batsman_1,batsman_2)
                    bowlers = "Current Bowlers: {} and {}".format(bowler_1, bowler_2)
                    final_msgs.append(batsmen)
                    final_msgs.append(bowlers)
                
                msg_2 = "Innings no:{} and {} overs have been bowled".format(innings, overs)
                final_msgs.append(comments['title'])
                if i == 0:
                    final_msgs.append(msg_2)
                if comments['isFour']:
                    final_msgs.append("Its a Boundary --4--")
                if comments['isSix']:
                    final_msgs.append("Its a maximum --6--")
                if comments['isWicket']:
                    final_msgs.append("Wicket down!")
                    final_msgs.append(comments['dismissalText']['commentary'])
                
                try:
                    final_msgs.append(comments['commentTextItems'][0]['html'])
                except:
                    pass
                if(i==0):
                    final_msgs.append("        RECENT HIGHLIGHTS         ")
                i+=1
    except:
        pass
    # Clearing HTML
    for i in range(len(final_msgs)):
        final_msgs[i] = cleanhtml(final_msgs[i])
    final_msgs.append("-------------------------------------------------")
    
    game_msgs.append(final_msgs)

# %%
for game in game_msgs:
    for msg in game:
        print(msg)
# Out:
# -----------------------------------------------------------------------------------------
# -------------------------------------NEW UPDATES ----------------------------------------
# --------------------------------------------------
# AUSTRALIA-VS-ENGLAND-2ND-TEST
# Day 4 - England need 386 runs.
# Status: Stumps
# Australia's score is: 473/9d and 230/9d
# England's score is: 236 and 82/4
# Starc to Root
# Innings no:4 and 43.2 overs have been bowled
# Wicket down!
# Joe Root c †Carey b Starc 24 (67b 1x4 0x6) SR: 35.82
# got him! Caught behind! Brilliant bowling. 140kph, angled towards off but wasn't close to off, Root thought he had to play, he leaned out to defend, it seamed away a touch and took the edge and Carey takes the chance low to his right!
#         RECENT HIGHLIGHTS
# Batsmen in crease: Ben Stokes and Joe Root
# Current Bowlers: Nathan Lyon and Mitchell Starc
# Lyon to Stokes
# good length, he sits back deep and defends
# Batsmen in crease: Joe Root and Ben Stokes
# Current Bowlers: Mitchell Starc and Nathan Lyon
# Starc to Root
# 139kph, full and wide, he mistimes this drive towards mid off
# Batsmen in crease: Ben Stokes and Joe Root
# Current Bowlers: Nathan Lyon and Mitchell Starc
# Lyon to Stokes
# tossed up on off, he defends on the front foot
# -------------------------------------------------
# --------------------------------------------------
# WELLINGTON-VS-CANTERBURY-9TH-MATCH
# Canterbury won by 6 wickets (with 21 balls remaining)
# Status: RESULT
# Wellington's score is: 151/9
# Canterbury's score is: 157/4
# Sears to Hay
# Innings no:2 and 16.3 overs have been bowled
# Its a maximum --6--
#         RECENT HIGHLIGHTS
# Batsmen in crease: Cam Fletcher and Matthew Hay
# Current Bowlers: Logan van Beek and Ben Sears
# van Beek to Fletcher
# Its a Boundary --4--
# van Beek to Bowes
# Wicket down!
# Chad Bowes b van Beek 62 (66m 41b 7x4 1x6) SR: 151.21
# Batsmen in crease: Cam Fletcher and Chad Bowes
# Current Bowlers: Ben Sears and Michael Bracewell
# Sears to Fletcher
# Its a maximum --6--
# Sears to Fletcher
# Its a maximum --6--
# Sears to Fletcher
# Its a Boundary --4--
# Batsmen in crease: Cam Fletcher and Chad Bowes
# Current Bowlers: Michael Bracewell and Peter Younghusband
# Bracewell to Fletcher
# Bracewell to Fletcher
# Its a Boundary --4--
# -------------------------------------------------
# --------------------------------------------------
# HONG-KONG-ISLANDERS-VS-KOWLOON-LIONS-3RD-MATCH
# Islanders won by 13 runs
# Status: RESULT
# Islanders's score is: 307
# Lions's score is: 294/8
# Batsmen in crease: Dan Pascoe and Hassan Khan Mohammad
# Current Bowlers: Dhananjay Rao and Haroon Arshad
# Dhananjay Rao to Pascoe
# Innings no:2 and 49.6 overs have been bowled
#         RECENT HIGHLIGHTS
# Dhananjay Rao to Aftab Hussain
# Wicket down!
# Aftab Hussain b Dhananjay Rao 3 (3b 0x4 0x6) SR: 100
# Dhananjay Rao to Zakir Hayat
# Wicket down!
# Zakir Hayat c Haroon Arshad b Dhananjay Rao 2 (3b 0x4 0x6) SR: 66.66
# Batsmen in crease: Aftab Hussain and Zakir Hayat
# Current Bowlers: Haroon Arshad and Yasim Murtaza
# Haroon Arshad to Aftab Hussain
# Haroon Arshad to Shahid Wasif
# Wicket down!
# Shahid Wasif c Babar Hayat b Haroon Arshad 14 (9b 1x4 1x6) SR: 155.55
# Haroon Arshad to Aizaz Khan
# Wicket down!
# Aizaz Khan c Coetzee b Haroon Arshad 116 (99b 12x4 6x6) SR: 117.17
# Batsmen in crease: Aizaz Khan and Shahid Wasif
# Current Bowlers: Yasim Murtaza and Dhananjay Rao
# Yasim Murtaza to Aizaz Khan
# Yasim Murtaza to Aizaz Khan
# Its a maximum --6--
# Yasim Murtaza to Aizaz Khan
# Its a maximum --6--
# -------------------------------------------------

# %%
import requests
import html

# %%
def telegram_bot_sendText(text_message):
    bot_token = '5019574567:AAGhEiWD4ZslxOBBNVI9-NUng8lmpeCiOnY'
    bot_chatid = '5029564645'
    send_text = 'https://api.telegram.org/bot' + bot_token + '/sendMessage?chat_id=' + bot_chatid + \
                 '&parse_mode=HTML&text=' + text_message
    response = requests.get(send_text)
    return response.json()

# %%
for game in game_msgs:
    for msg in game:
        telegram_bot_sendText(msg)
